# %% [markdown]
# <a href="https://colab.research.google.com/github/cyzcz1/Blogin/blob/master/LLaVA_7b_8bit_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b 5GB https://github.com/camenduru/LLaVA
# %cd /content/LLaVA

# !pip install -q transformers==4.36.2
# !pip install ninja
# !pip install flash-attn --no-build-isolation

# !pip install -e .

# !python -m llava.serve.cli \
#     --model-path 4bit/llava-v1.5-7b-5GB \
#     --image-file "https://llava-vl.github.io/static/images/view.jpg" \
#     --load-8bit
# Out:
# /content
# Cloning into 'LLaVA'...
# remote: Enumerating objects: 1960, done.
# remote: Total 1960 (delta 0), reused 0 (delta 0), pack-reused 1960 (from 1)
# Receiving objects: 100% (1960/1960), 13.60 MiB | 17.01 MiB/s, done.
# Resolving deltas: 100% (1173/1173), done.
# /content/LLaVA
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 67.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 70.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.36.2 which is incompatible.
# Collecting ninja
#   Downloading ninja-1.11.1.3-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.3 kB)
# Downloading ninja-1.11.1.3-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1.3
# Collecting flash-attn
#   Downloading flash_attn-2.7.2.post1.tar.gz (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 41.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash-attn) (2.5.1+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from flash-attn) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->flash-attn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash-attn) (3.0.2)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.7.2.post1-cp310-cp310-linux_x86_64.whl size=190160474 sha256=0b454d9e650bfc437cc71335080172a5d05f51eab355636c9d5b7321fec7318e
#   Stored in directory: /root/.cache/pip/wheels/da/ec/5b/b2c37a8e4f755ad82492a822463bca0817f0e0e11de874b550
# Successfully built flash-attn
# Installing collected packages: flash-attn
# Successfully installed flash-attn-2.7.2.post1
# Obtaining file:///content/LLaVA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from llava==1.1.0) (0.8.0)
# Collecting fastapi (from llava==1.1.0)
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting gradio==3.35.2 (from llava==1.1.0)
#   Downloading gradio-3.35.2-py3-none-any.whl.metadata (15 kB)
# Collecting markdown2[all] (from llava==1.1.0)
#   Downloading markdown2-2.5.2-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llava==1.1.0) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from llava==1.1.0) (2.32.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from llava==1.1.0) (0.2.0)
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from llava==1.1.0) (0.15.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from llava==1.1.0) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from llava==1.1.0) (0.20.1+cu121)
# Collecting uvicorn (from llava==1.1.0)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (from llava==1.1.0) (0.18.7)
# Collecting shortuuid (from llava==1.1.0)
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Collecting httpx==0.24.0 (from llava==1.1.0)
#   Downloading httpx-0.24.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting deepspeed==0.9.5 (from llava==1.1.0)
#   Downloading deepspeed-0.9.5.tar.gz (809 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.9/809.9 kB 22.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting peft==0.4.0 (from llava==1.1.0)
#   Downloading peft-0.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting transformers==4.31.0 (from llava==1.1.0)
#   Downloading transformers-4.31.0-py3-none-any.whl.metadata (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 11.3 MB/s eta 0:00:00
# Collecting accelerate==0.21.0 (from llava==1.1.0)
#   Downloading accelerate-0.21.0-py3-none-any.whl.metadata (17 kB)
# Collecting bitsandbytes==0.41.0 (from llava==1.1.0)
#   Downloading bitsandbytes-0.41.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting scikit-learn==1.2.2 (from llava==1.1.0)
#   Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting sentencepiece (from llava==1.1.0)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting einops (from llava==1.1.0)
#   Downloading einops-0.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting einops-exts==0.0.4 (from llava==1.1.0)
#   Downloading einops_exts-0.0.4-py3-none-any.whl.metadata (621 bytes)
# Collecting timm==0.6.13 (from llava==1.1.0)
#   Downloading timm-0.6.13-py3-none-any.whl.metadata (38 kB)
# Collecting gradio_client==0.2.9 (from llava==1.1.0)
#   Downloading gradio_client-0.2.9-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->llava==1.1.0) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->llava==1.1.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->llava==1.1.0) (6.0.2)
# Collecting hjson (from deepspeed==0.9.5->llava==1.1.0)
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.5->llava==1.1.0) (1.11.1.3)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.5->llava==1.1.0) (9.0.0)
# Collecting pydantic<2.0.0 (from deepspeed==0.9.5->llava==1.1.0)
#   Downloading pydantic-1.10.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.6/152.6 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.9.5->llava==1.1.0) (4.66.6)
# Collecting aiofiles (from gradio==3.35.2->llava==1.1.0)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.11.10)
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (5.5.0)
# Collecting ffmpy (from gradio==3.35.2->llava==1.1.0)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (0.26.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.1.4)
# Requirement already satisfied: markdown-it-py>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.35.2->llava==1.1.0) (3.0.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.8.0)
# Collecting mdit-py-plugins<=0.3.3 (from gradio==3.35.2->llava==1.1.0)
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: orjson in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.10.12)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (11.0.0)
# Collecting pydub (from gradio==3.35.2->llava==1.1.0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pygments>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (2.18.0)
# Collecting python-multipart (from gradio==3.35.2->llava==1.1.0)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting semantic-version (from gradio==3.35.2->llava==1.1.0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.35.2->llava==1.1.0) (14.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio_client==0.2.9->llava==1.1.0) (2024.10.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from gradio_client==0.2.9->llava==1.1.0) (4.12.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.24.0->llava==1.1.0) (2024.8.30)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx==0.24.0->llava==1.1.0)
#   Downloading httpcore-0.17.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx==0.24.0->llava==1.1.0) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.24.0->llava==1.1.0) (1.3.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft==0.4.0->llava==1.1.0) (0.4.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->llava==1.1.0) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->llava==1.1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.2.2->llava==1.1.0) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->llava==1.1.0) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->llava==1.1.0) (2024.9.11)
# Collecting tokenizers>=0.12.1 (from llava==1.1.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->llava==1.1.0) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->llava==1.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->llava==1.1.0) (1.3.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn->llava==1.1.0) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn->llava==1.1.0) (0.14.0)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi->llava==1.1.0)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting wavedrom (from markdown2[all]->llava==1.1.0)
#   Downloading wavedrom-2.0.3.post3.tar.gz (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.7/137.7 kB 13.0 MB/s eta 0:00:00
#   Downloading mdit_py_plugins-0.3.1-py3-none-any.whl.metadata (2.8 kB)
#   Downloading mdit_py_plugins-0.3.0-py3-none-any.whl.metadata (2.8 kB)
#   Downloading mdit_py_plugins-0.2.8-py3-none-any.whl.metadata (2.8 kB)
#   Downloading mdit_py_plugins-0.2.7-py3-none-any.whl.metadata (2.8 kB)
#   Downloading mdit_py_plugins-0.2.6-py3-none-any.whl.metadata (2.6 kB)
#   Downloading mdit_py_plugins-0.2.5-py3-none-any.whl.metadata (2.6 kB)
# INFO: pip is still looking at multiple versions of mdit-py-plugins to determine which version is compatible with other requirements. This could take a while.
#   Downloading mdit_py_plugins-0.2.4-py3-none-any.whl.metadata (2.6 kB)
#   Downloading mdit_py_plugins-0.2.3-py3-none-any.whl.metadata (2.6 kB)
#   Downloading mdit_py_plugins-0.2.2-py3-none-any.whl.metadata (2.6 kB)
#   Downloading mdit_py_plugins-0.2.1-py3-none-any.whl.metadata (2.6 kB)
#   Downloading mdit_py_plugins-0.2.0-py3-none-any.whl.metadata (2.6 kB)
# INFO: This is taking longer than usual. You might need to provide the dependency resolver with stricter constraints to reduce runtime. See https://pip.pypa.io/warnings/backtracking for guidance. If you want to abort this run, press Ctrl + C.
#   Downloading mdit_py_plugins-0.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting markdown-it-py[linkify]>=2.0.0 (from gradio==3.35.2->llava==1.1.0)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (1.18.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->gradio==3.35.2->llava==1.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->gradio==3.35.2->llava==1.1.0) (2024.2)
# Collecting svgwrite (from wavedrom->markdown2[all]->llava==1.1.0)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx==0.24.0->llava==1.1.0) (1.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->llava==1.1.0) (5.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.35.2->llava==1.1.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.35.2->llava==1.1.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.35.2->llava==1.1.0) (0.22.3)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.35.2->llava==1.1.0) (1.0.3)
# Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 21.0 MB/s eta 0:00:00
# Downloading bitsandbytes-0.41.0-py3-none-any.whl (92.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.6 MB/s eta 0:00:00
# Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.0 MB/s eta 0:00:00
# Downloading einops_exts-0.0.4-py3-none-any.whl (3.9 kB)
# Downloading gradio-3.35.2-py3-none-any.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 84.5 MB/s eta 0:00:00
# Downloading gradio_client-0.2.9-py3-none-any.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.8/288.8 kB 24.1 MB/s eta 0:00:00
# Downloading httpx-0.24.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 7.5 MB/s eta 0:00:00
# Downloading peft-0.4.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 7.2 MB/s eta 0:00:00
# Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 116.9 MB/s eta 0:00:00
# Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.9 MB/s eta 0:00:00
# Downloading timm-0.6.13-py3-none-any.whl (549 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 34.3 MB/s eta 0:00:00
# Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 114.0 MB/s eta 0:00:00
# Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 117.4 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.4 MB/s eta 0:00:00
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 9.7 MB/s eta 0:00:00
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 7.8 MB/s eta 0:00:00
# Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 9.1 MB/s eta 0:00:00
# Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 4.8 MB/s eta 0:00:00
# Downloading pydantic-1.10.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 102.4 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 8.2 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.7 MB/s eta 0:00:00
# Downloading latex2mathml-3.77.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 8.1 MB/s eta 0:00:00
# Downloading markdown2-2.5.2-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 5.3 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 6.9 MB/s eta 0:00:00
# Building wheels for collected packages: llava, deepspeed, wavedrom
#   Building editable for llava (pyproject.toml) ... done
#   Created wheel for llava: filename=llava-1.1.0-0.editable-py3-none-any.whl size=14861 sha256=08b8bf64eacf521c0373ec6e3422faba75524678cabfdbb57d61ea363803cdc8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-czroijkr/wheels/04/eb/cc/8992f8302dd174d3e63566efe82795f070b535b03506b75ffb
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.9.5-py3-none-any.whl size=844530 sha256=e07e35353926358d9733c0b01038c95459d693ee8a7a7313716dcbf356845530
#   Stored in directory: /root/.cache/pip/wheels/7e/a9/bb/a00d383521da14dc91b65ae2d0062401b750d968a548401b2a
#   Building wheel for wavedrom (setup.py) ... done
#   Created wheel for wavedrom: filename=wavedrom-2.0.3.post3-py2.py3-none-any.whl size=30052 sha256=8289080516976096a258d3a7ec1b5558e5ae0368dc5f54c8c1cc048c12b4b8f8
#   Stored in directory: /root/.cache/pip/wheels/9c/52/8c/38b454b42f712f325e26f633287484c7dc1ad469e1580c5954
# Successfully built llava deepspeed wavedrom
# Installing collected packages: tokenizers, sentencepiece, pydub, hjson, bitsandbytes, uvicorn, svgwrite, shortuuid, semantic-version, python-multipart, pydantic, markdown2, markdown-it-py, latex2mathml, ffmpy, einops, aiofiles, wavedrom, starlette, scikit-learn, mdit-py-plugins, httpcore, einops-exts, transformers, httpx, fastapi, deepspeed, accelerate, timm, peft, gradio_client, gradio, llava
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.0
#     Uninstalling sentencepiece-0.2.0:
#       Successfully uninstalled sentencepiece-0.2.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.3
#     Uninstalling pydantic-2.10.3:
#       Successfully uninstalled pydantic-2.10.3
#   Attempting uninstall: markdown-it-py
#     Found existing installation: markdown-it-py 3.0.0
#     Uninstalling markdown-it-py-3.0.0:
#       Successfully uninstalled markdown-it-py-3.0.0
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.0
#     Uninstalling einops-0.8.0:
#       Successfully uninstalled einops-0.8.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
#   Attempting uninstall: mdit-py-plugins
#     Found existing installation: mdit-py-plugins 0.4.2
#     Uninstalling mdit-py-plugins-0.4.2:
#       Successfully uninstalled mdit-py-plugins-0.4.2
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.36.2
#     Uninstalling transformers-4.36.2:
#       Successfully uninstalled transformers-4.36.2
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.1.1
#     Uninstalling accelerate-1.1.1:
#       Successfully uninstalled accelerate-1.1.1
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.12
#     Uninstalling timm-1.0.12:
#       Successfully uninstalled timm-1.0.12
#   Attempting uninstall: peft
#     Found existing installation: peft 0.13.2
#     Uninstalling peft-0.13.2:
#       Successfully uninstalled peft-0.13.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.20 requires pydantic>=2.7.0, but you have pydantic 1.10.19 which is incompatible.
# google-genai 0.2.2 requires pydantic<3.0.0dev,>=2.0.0, but you have pydantic 1.10.19 which is incompatible.
# langchain 0.3.11 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.19 which is incompatible.
# langchain-core 0.3.24 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.19 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.31.0 which is incompatible.
# Successfully installed accelerate-0.21.0 aiofiles-24.1.0 bitsandbytes-0.41.0 deepspeed-0.9.5 einops-0.6.1 einops-exts-0.0.4 fastapi-0.115.6 ffmpy-0.4.0 gradio-3.35.2 gradio_client-0.2.9 hjson-3.1.0 httpcore-0.17.3 httpx-0.24.0 latex2mathml-3.77.0 llava-1.1.0 markdown-it-py-2.2.0 markdown2-2.5.2 mdit-py-plugins-0.3.3 peft-0.4.0 pydantic-1.10.19 pydub-0.25.1 python-multipart-0.0.20 scikit-learn-1.2.2 semantic-version-2.10.0 sentencepiece-0.1.99 shortuuid-1.0.13 starlette-0.41.3 svgwrite-1.4.3 timm-0.6.13 tokenizers-0.13.3 transformers-4.31.0 uvicorn-0.34.0 wavedrom-2.0.3.post3

# %%
import threading
import subprocess
threading.Thread(target=lambda: subprocess.run(['python3', '-m', 'llava.serve.controller', '--host', '0.0.0.0', '--port', '10000'], check=True), daemon=True).start()

# %%
import threading
import subprocess
command = [
    'python3', '-m', 'llava.serve.model_worker',
    '--host', '0.0.0.0',
    '--controller', 'http://localhost:10000',
    '--port', '40000',
    '--worker', 'http://localhost:40000',
    '--model-path', '4bit/llava-v1.5-7b-5GB',
    '--load-8bit'
]
threading.Thread(target=lambda: subprocess.run(command, check=True, shell=False), daemon=True).start()

# %%
# !python3 -m llava.serve.gradio_web_server --controller http://localhost:10000 --model-list-mode reload --share
# Out:
# [2024-12-18 14:24:38,636] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /usr/local/lib/python3.10/dist-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /usr/local/lib/python3.10/dist-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# 2024-12-18 14:24:39.815068: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-18 14:24:39.834240: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-18 14:24:39.840100: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-18 14:24:41.623339: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 14:24:45 | INFO | gradio_web_server | args: Namespace(host='0.0.0.0', port=None, controller_url='http://localhost:10000', concurrency_count=10, model_list_mode='reload', share=True, moderate=False, embed=False)
# 2024-12-18 14:24:45 | INFO | gradio_web_server | Models: ['llava-v1.5-7b-5GB']
# 2024-12-18 14:24:45 | INFO | gradio_web_server | Namespace(host='0.0.0.0', port=None, controller_url='http://localhost:10000', concurrency_count=10, model_list_mode='reload', share=True, moderate=False, embed=False)
# 2024-12-18 14:24:45 | INFO | stdout | Running on local URL:  http://0.0.0.0:7860
# 2024-12-18 14:24:45 | INFO | stdout | Running on public URL: https://9ad25f72d78789faa2.gradio.live
# 2024-12-18 14:24:45 | INFO | stdout |
# 2024-12-18 14:24:45 | INFO | stdout | This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# 2024-12-18 14:24:56 | INFO | gradio_web_server | load_demo. ip: 172.31.42.128
# 2024-12-18 14:24:56 | INFO | gradio_web_server | Models: ['llava-v1.5-7b-5GB']
# 2024-12-18 14:25:11 | INFO | gradio_web_server | add_text. ip: 172.31.42.128. len: 6
# 2024-12-18 14:25:13 | INFO | gradio_web_server | http_bot. ip: 172.31.42.128
# 2024-12-18 14:25:13 | INFO | gradio_web_server | model_name: llava-v1.5-7b-5GB, worker_addr: http://localhost:40000
# 2024-12-18 14:25:13 | INFO | gradio_web_server | ==== request ====
# {'model': 'llava-v1.5-7b-5GB', 'prompt': "A chat between a curious human and an artificial intelligence assistant. The assistant gives helpful, detailed, and polite answers to the human's questions. USER: \n简历写的什么 ASSISTANT:", 'temperature': 0.2, 'top_p': 0.7, 'max_new_tokens': 512, 'stop': '</s>', 'images': "List of 1 images: ['6c8181954bcf5ee889b89572eb6f3b65']"}
# 2024-12-18 14:25:31 | INFO | gradio_web_server | 简历写的是一个中文的简历，其中包含了个人的基本信息，如姓名、联系方式、工作经历等。
# 2024-12-18 14:26:26 | INFO | gradio_web_server | add_text. ip: 172.31.42.128. len: 19
# 2024-12-18 14:26:28 | INFO | gradio_web_server | http_bot. ip: 172.31.42.128
# 2024-12-18 14:26:28 | INFO | gradio_web_server | model_name: llava-v1.5-7b-5GB, worker_addr: http://localhost:40000
# 2024-12-18 14:26:28 | INFO | gradio_web_server | ==== request ====
# {'model': 'llava-v1.5-7b-5GB', 'prompt': "A chat between a curious human and an artificial intelligence assistant. The assistant gives helpful, detailed, and polite answers to the human's questions. USER: \nexplain the picture ASSISTANT:", 'temperature': 0.2, 'top_p': 0.7, 'max_new_tokens': 512, 'stop': '</s>', 'images': "List of 1 images: ['6e8aa4255a1f92a2585b0e1b0a1ba818']"}
# 2024-12-18 14:26:58 | INFO | gradio_web_server | The image depicts a group of three people walking together in a grassy field, enjoying the outdoors. They are walking in a line, with one person slightly ahead of the others. The field is surrounded by trees, providing a serene and natural setting for their walk.
#
# Each person is carrying a backpack, suggesting they might be on a hiking or camping trip. The backpacks are visible on their backs, with one person's backpack being closer to the left side of the image, another person's backpack in the middle, and the third person's backpack on the right side.
# 2024-12-18 14:28:26 | INFO | gradio_web_server | downvote. ip: 172.31.42.128
# 2024-12-18 14:28:33 | INFO | gradio_web_server | regenerate. ip: 172.31.42.128
# 2024-12-18 14:28:35 | INFO | gradio_web_server | http_bot. ip: 172.31.42.128
# 2024-12-18 14:28:35 | INFO | gradio_web_server | model_name: llava-v1.5-7b-5GB, worker_addr: http://localhost:40000
# 2024-12-18 14:28:35 | INFO | gradio_web_server | ==== request ====
# {'model': 'llava-v1.5-7b-5GB', 'prompt': "A chat between a curious human and an artificial intelligence assistant. The assistant gives helpful, detailed, and polite answers to the human's questions. USER: \nexplain the picture ASSISTANT:", 'temperature': 0.2, 'top_p': 0.7, 'max_new_tokens': 512, 'stop': '</s>', 'images': "List of 1 images: ['6e8aa4255a1f92a2585b0e1b0a1ba818']"}
# 2024-12-18 14:29:02 | INFO | gradio_web_server | The image depicts a group of three people walking together in a grassy field, enjoying the outdoors. They are walking in a line, with one person slightly ahead of the others. The field is surrounded by trees, providing a serene and natural setting for their walk.
#
# Each person is carrying a backpack, suggesting they might be on a hiking or camping trip. The backpacks are visible on their backs, with one located near the center of the group, another slightly to the left, and the third one on the right side.
# 2024-12-18 14:29:50 | INFO | stdout | Keyboard interruption in main thread... closing server.
# 2024-12-18 14:29:50 | ERROR | stderr | Traceback (most recent call last):
# 2024-12-18 14:29:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2058, in block_thread
# 2024-12-18 14:29:50 | ERROR | stderr |     time.sleep(0.1)
# 2024-12-18 14:29:50 | ERROR | stderr | KeyboardInterrupt
# 2024-12-18 14:29:50 | ERROR | stderr |
# 2024-12-18 14:29:50 | ERROR | stderr | During handling of the above exception, another exception occurred:
# 2024-12-18 14:29:50 | ERROR | stderr |
# 2024-12-18 14:29:50 | ERROR | stderr | Traceback (most recent call last):
# 2024-12-18 14:29:50 | ERROR | stderr |   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
# 2024-12-18 14:29:50 | ERROR | stderr |     return _run_code(code, main_globals, None,
# 2024-12-18 14:29:50 | ERROR | stderr |   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
# 2024-12-18 14:29:50 | ERROR | stderr |     exec(code, run_globals)
# 2024-12-18 14:29:50 | ERROR | stderr |   File "/content/LLaVA/llava/serve/gradio_web_server.py", line 413, in <module>
# 2024-12-18 14:29:50 | ERROR | stderr |     demo.queue(
# 2024-12-18 14:29:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1975, in launch
# 2024-12-18 14:29:50 | ERROR | stderr |     self.block_thread()
# 2024-12-18 14:29:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2061, in block_thread
# 2024-12-18 14:29:50 | ERROR | stderr |     self.server.close()
# 2024-12-18 14:29:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/dist-packages/gradio/networking.py", line 43, in close
# 2024-12-18 14:29:50 | ERROR | stderr |     self.thread.join()
# 2024-12-18 14:29:50 | ERROR | stderr |   File "/usr/lib/python3.10/threading.py", line 1096, in join
# 2024-12-18 14:29:50 | ERROR | stderr |     self._wait_for_tstate_lock()
# 2024-12-18 14:29:50 | ERROR | stderr |   File "/usr/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
# 2024-12-18 14:29:50 | ERROR | stderr |     if lock.acquire(block, timeout):
# 2024-12-18 14:29:50 | ERROR | stderr | KeyboardInterrupt
# 2024-12-18 14:29:50 | INFO | stdout | Killing tunnel 0.0.0.0:7860 <> https://9ad25f72d78789faa2.gradio.live
# ^C
